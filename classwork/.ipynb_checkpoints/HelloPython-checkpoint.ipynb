# %% [markdown]
# Hello Python! This is my first notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Any String")
# Out:
# Any String

# %%
print(5+10)
# Out:
# 15

# %%
print(True)
# Out:
# True

# %%
print("Hello Class!")
print("Tacc's awesome")

# %%
2.3+5.5
# Out:
# 7.8

# %%
name = "Charlie"
print (name)
# Out:
# Charlie

# %%
num1 = 5
a = "Hello"
b = True
type(a)
type(b)
# Out:
# bool

# %%
1+1
# Out:
# 2

# %%
num1 = 5.0/2
num2 = 5/2

# %%
myfile = open("test.dat", "w")
myfile.write("7")
myfile.write("HelloWorld")
myfile.close()

# %%
myfile2 = open("test.dat", 'r')
content = myfile2.read()
myfile2.close()
print(content)
# Out:
# 7HelloWorld

# %%
a = 2
b=3
print(a!=b or a<b)
# Out:
# True

# %%
if (b>a):
    print("B is greater than A")
    print("Conditionals are awesome!")
# Out:
# B is greater than A
# Conditionals are awesome!

# %%
for r in range(1,3):
    print(r, r**2)
# Out:
# 1 1
# 2 4

# %%
mylist = ["Charlie", 10, "yellow", 42, "Alex", 9, "black", 21]

# %%
for t in mylist:
    print(t)
# Out:
# Charlie
# 10
# yellow
# 42
# Alex
# 9
# black
# 21

# %%
print(mylist[3:6])
# Out:
# [42, 'Alex', 9]

# %%
print("43" in mylist)
# Out:
# False

# %%
import math

def calc_hyp(a, b):
    h= sqrt(a*a, b*b)
    return h

# %%
my_h = calc_hyp(3, 4)
print(my_h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-afd0bc9b544c> in <module>
# ----> 1 my_h = calc_hyp(3, 4)
#       2 print(my_h)
#
# <ipython-input-38-7ed49e305672> in calc_hyp(a, b)
#       2
#       3 def calc_hyp(a, b):
# ----> 4     h= sqrt(a*a, b*b)
#       5     return h
#
# NameError: name 'sqrt' is not defined

# %%
import random

def montecarlo_pi(number_of_shots):
    counter = 0
    for i in range(0, number_of_shots):
        x = random.uniform(-1,1)
        y = random.uniform(-1,1)
       
        if (x*x + y*y < 1):
            number_of_hits = number_of_hits + 1
            
    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(50)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-51-47413f1e6965> in <module>
# ----> 1 montecarlo_pi(50)
#
# <ipython-input-50-ffe55ee555fd> in montecarlo_pi(number_of_shots)
#       8
#       9         if (x*x + y*y < 1):
# ---> 10             number_of_hits = number_of_hits + 1
#      11
#      12     return 4*number_of_hits/number_of_shots
#
# UnboundLocalError: local variable 'number_of_hits' referenced before assignment

# %%
im
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-e371e598fe9f> in <module>
# ----> 1 im
#
# NameError: name 'im' is not defined
