# %% [markdown]
# I'm abt to write my first Jupyter Notebook in Python.

# %% [markdown]
# # Let's start with Hello World!

# %% [markdown]
# ## HEre is a subheading

# %%
print ("HEllo world")
# Out:
# HEllo world
